# %% [markdown]
# # MODELLING - REGRESSION

# %% [markdown]
# Goal: choose the algorithm that performs better and its hyperparameters.
#
#
# **IMPORTANT:** This stage is designed for a high-level (maximum-scope) modeling view, in which we compare many algorithms and also many parameters.
# If we experience memory or performance issues, we should reduce the problem by:
# - Sampling the data
# - Applying undersampling for balancing
# - Reducing the number of algorithms to test
# - Reducing the number of parameters to test
# - Using random search and specifying an appropriate n_iter

# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.pipeline import Pipeline

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Autocomplete
# %config IPCompleter.greedy=True

# Disable scientific notation
pd.options.display.float_format = '{:.2f}'.format

# Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## IMPORT DATA

# %%
PROJECT_PATH = '/Users/rober/cmapss-rul-prediction/'

# %%
name_X = 'X_preselected.pickle'
name_y = 'y_preselected.pickle'

# %%
X = pd.read_pickle(PROJECT_PATH + '/02_Data/03_Working/' + name_X)
y = pd.read_pickle(PROJECT_PATH + '/02_Data/03_Working/' + name_y)

# %% [markdown]
# ## MODELLING

# %% [markdown]
# ### Set aside the validation dataset

# %% [markdown]
# We'll stick to the common approach of **50/30/20 (train/test/validation)**.
#
# This approach prioritizes reliable evaluation and minimizes overfitting, while still leaving enough data for effective model learning given the dataset’s size (~14K rows).

# %%
train_X,val_X,train_y,val_y = train_test_split(X,y,test_size=0.3)

# %% [markdown]
# ### Create the pipeline and the dictionary of algorithms, parameters, and values to test.

# %% [markdown]
# Modify to keep only the algorithms you want to test.
#
# Adjust the parameters accordingly.

# %%
pipe = Pipeline([('algorithm', RandomForestRegressor())])

grid = [
    {'algorithm': [LinearRegression()],
     'algorithm__n_jobs': [-1]},
    
    {'algorithm': [RandomForestRegressor()],
     'algorithm__n_jobs': [-1],
     'algorithm__max_depth': [5, 10, 15],
     'algorithm__n_estimators': [50, 100, 200]},
    
    {'algorithm': [XGBRegressor()],
     'algorithm__n_jobs': [-1],
     'algorithm__learning_rate': [0.01, 0.025, 0.05, 0.1],
     'algorithm__max_depth': [5, 10, 20],
     'algorithm__reg_alpha': [0, 0.1, 0.5, 1],
     'algorithm__reg_lambda': [0.01, 0.1, 1],
     'algorithm__n_estimators': [100, 500, 1000]},
    
    {'algorithm': [HistGradientBoostingRegressor()],
     'algorithm__learning_rate': [0.01, 0.025, 0.05, 0.1],
     'algorithm__max_iter': [50, 100, 200],
     'algorithm__max_depth': [5, 10, 20],
     'algorithm__min_samples_leaf': [500],
     'algorithm__scoring': ['neg_mean_absolute_percentage_error'],
     'algorithm__l2_regularization': [0, 0.25, 0.5, 0.75, 1]}
]

# %% [markdown]
# ### Optimize the hyperparameters

# %% [markdown]
# We'll use **RandomizedSearchCV** instead of GridSearch because:
# - It’s faster — it tests only a random subset of all combinations instead of every single one.
# - It still gives excellent results if you set a reasonable n_iter (e.g., 20–50).
# - It’s ideal when you have many parameters or large grids — like in your setup with several algorithms and many tuning values.

# %% [markdown]
# ####  Grid search

# %%
# grid_search = GridSearchCV(estimator= pipe, 
#                            param_grid = grid, 
#                            cv = 3, 
#                            scoring = 'neg_mean_absolute_percentage_error',
#                            verbose = 0,
#                            n_jobs = -1)

# modelo = grid_search.fit(train_X,train_y)

# pd.DataFrame(grid_search.cv_results_).sort_values(by = 'rank_test_score')

# %% [markdown]
# ####  Random search

# %%
random_search = RandomizedSearchCV(estimator = pipe,
                                   param_distributions = grid, 
                                   n_iter = 25, 
                                   cv = 3, 
                                   scoring = 'neg_root_mean_squared_error', 
                                   verbose = 0,
                                   n_jobs = -1)

model = random_search.fit(train_X,train_y)

pd.DataFrame(random_search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 14           0.23          0.02             0.02            0.01
# 0            0.41          0.01             0.03            0.00
# 1            5.14          0.08             0.11            0.01
# 17           2.21          0.10             0.06            0.01
# 15           4.53          0.12             0.14            0.03
# 2            6.29          0.36             0.05            0.02
# 10           2.35          0.13             0.05            0.00
# 24           1.99          0.03             0.07            0.01
# 7           23.97          0.53             0.23            0.01
# 20          23.29          1.02             0.22            0.00
# 12          17.38          0.30             0.18            0.05
# 16           5.03          0.05             0.05            0.02
# 9            0.20          0.03             0.01            0.00
# 6            0.20          0.02             0.01            0.00
# 13           0.34          0.07             0.03            0.01
# 18          27.89          0.68             0.38            0.07
# 23          24.36          1.28             0.20            0.05
# 22          26.77          0.62             0.32            0.01
# 19          48.35          1.19             0.39            0.03
# 21           0.34          0.04             0.03            0.00
# 11          66.58          2.82             0.71            0.08
# 8          153.63          1.42             1.35            0.26
# 5           38.98          0.46             0.26            0.07
# 4           87.67          5.71             0.98            0.07
# 3          316.45          1.90             2.27            0.06
#
#               param_algorithm__scoring  param_algorithm__min_samples_leaf  \
# 14  neg_mean_absolute_percentage_error                             500.00
# 0   neg_mean_absolute_percentage_error                             500.00
# 1                                  NaN                                NaN
# 17                                 NaN                                NaN
# 15                                 NaN                                NaN
# 2                                  NaN                                NaN
# 10                                 NaN                                NaN
# 24                                 NaN                                NaN
# 7                                  NaN                                NaN
# 20                                 NaN                                NaN
# 12                                 NaN                                NaN
# 16                                 NaN                                NaN
# 9   neg_mean_absolute_percentage_error                             500.00
# 6   neg_mean_absolute_percentage_error                             500.00
# 13  neg_mean_absolute_percentage_error                             500.00
# 18                                 NaN                                NaN
# 23                                 NaN                                NaN
# 22                                 NaN                                NaN
# 19                                 NaN                                NaN
# 21  neg_mean_absolute_percentage_error                             500.00
# 11                                 NaN                                NaN
# 8                                  NaN                                NaN
# 5                                  NaN                                NaN
# 4                                  NaN                                NaN
# 3                                  NaN                                NaN
#
#     param_algorithm__max_iter  param_algorithm__max_depth  \
# 14                      50.00                          10
# 0                      100.00                          20
# 1                         NaN                           5
# 17                        NaN                           5
# 15                        NaN                           5
# 2                         NaN                          10
# 10                        NaN                           5
# 24                        NaN                           5
# 7                         NaN                          10
# 20                        NaN                          10
# 12                        NaN                          10
# 16                        NaN                          10
# 9                       50.00                          10
# 6                       50.00                           5
# 13                      50.00                          10
# 18                        NaN                          10
# 23                        NaN                          10
# 22                        NaN                          10
# 19                        NaN                          20
# 21                     100.00                          20
# 11                        NaN                          20
# 8                         NaN                          20
# 5                         NaN                          20
# 4                         NaN                          20
# 3                         NaN                          20
#
#     param_algorithm__learning_rate  param_algorithm__l2_regularization  ...  \
# 14                            0.10                                0.00  ...
# 0                             0.10                                0.25  ...
# 1                             0.01                                 NaN  ...
# 17                            0.05                                 NaN  ...
# 15                            0.03                                 NaN  ...
# 2                             0.03                                 NaN  ...
# 10                            0.10                                 NaN  ...
# 24                            0.10                                 NaN  ...
# 7                             0.01                                 NaN  ...
# 20                            0.01                                 NaN  ...
# 12                            0.03                                 NaN  ...
# 16                            0.05                                 NaN  ...
# 9                             0.03                                0.00  ...
# 6                             0.03                                0.25  ...
# 13                            0.03                                0.50  ...
# 18                            0.05                                 NaN  ...
# 23                            0.03                                 NaN  ...
# 22                            0.10                                 NaN  ...
# 19                            0.10                                 NaN  ...
# 21                            0.01                                1.00  ...
# 11                            0.05                                 NaN  ...
# 8                             0.01                                 NaN  ...
# 5                             0.05                                 NaN  ...
# 4                             0.05                                 NaN  ...
# 3                             0.01                                 NaN  ...
#
#    param_algorithm__reg_alpha  param_algorithm__n_jobs  \
# 14                        NaN                      NaN
# 0                         NaN                      NaN
# 1                        0.00                    -1.00
# 17                       0.10                    -1.00
# 15                       1.00                    -1.00
# 2                        0.50                    -1.00
# 10                       0.10                    -1.00
# 24                       0.10                    -1.00
# 7                        0.10                    -1.00
# 20                       0.10                    -1.00
# 12                       1.00                    -1.00
# 16                       0.10                    -1.00
# 9                         NaN                      NaN
# 6                         NaN                      NaN
# 13                        NaN                      NaN
# 18                       0.50                    -1.00
# 23                       0.10                    -1.00
# 22                       0.50                    -1.00
# 19                       0.50                    -1.00
# 21                        NaN                      NaN
# 11                       1.00                    -1.00
# 8                        0.50                    -1.00
# 5                        0.00                    -1.00
# 4                        0.50                    -1.00
# 3                        0.10                    -1.00
#
#     param_algorithm__n_estimators  \
# 14                            NaN
# 0                             NaN
# 1                         1000.00
# 17                         500.00
# 15                        1000.00
# 2                          100.00
# 10                         500.00
# 24                         500.00
# 7                          500.00
# 20                         500.00
# 12                         500.00
# 16                         100.00
# 9                             NaN
# 6                             NaN
# 13                            NaN
# 18                        1000.00
# 23                        1000.00
# 22                        1000.00
# 19                         500.00
# 21                            NaN
# 11                         500.00
# 8                          500.00
# 5                          100.00
# 4                         1000.00
# 3                         1000.00
#
#                                                params  split0_test_score  \
# 14  {'algorithm__scoring': 'neg_mean_absolute_perc...             -40.15
# 0   {'algorithm__scoring': 'neg_mean_absolute_perc...             -40.17
# 1   {'algorithm__reg_lambda': 0.1, 'algorithm__reg...             -40.59
# 17  {'algorithm__reg_lambda': 1, 'algorithm__reg_a...             -41.38
# 15  {'algorithm__reg_lambda': 1, 'algorithm__reg_a...             -41.41
# 2   {'algorithm__reg_lambda': 0.1, 'algorithm__reg...             -42.91
# 10  {'algorithm__reg_lambda': 0.01, 'algorithm__re...             -43.03
# 24  {'algorithm__reg_lambda': 0.1, 'algorithm__reg...             -43.23
# 7   {'algorithm__reg_lambda': 0.1, 'algorithm__reg...             -43.29
# 20  {'algorithm__reg_lambda': 0.01, 'algorithm__re...             -43.42
# 12  {'algorithm__reg_lambda': 1, 'algorithm__reg_a...             -43.44
# 16  {'algorithm__reg_lambda': 0.01, 'algorithm__re...             -43.47
# 9   {'algorithm__scoring': 'neg_mean_absolute_perc...             -43.83
# 6   {'algorithm__scoring': 'neg_mean_absolute_perc...             -43.84
# 13  {'algorithm__scoring': 'neg_mean_absolute_perc...             -43.85
# 18  {'algorithm__reg_lambda': 1, 'algorithm__reg_a...             -44.44
# 23  {'algorithm__reg_lambda': 0.1, 'algorithm__reg...             -44.45
# 22  {'algorithm__reg_lambda': 1, 'algorithm__reg_a...             -44.64
# 19  {'algorithm__reg_lambda': 1, 'algorithm__reg_a...             -45.31
# 21  {'algorithm__scoring': 'neg_mean_absolute_perc...             -45.97
# 11  {'algorithm__reg_lambda': 0.1, 'algorithm__reg...             -48.66
# 8   {'algorithm__reg_lambda': 0.1, 'algorithm__reg...             -49.70
# 5   {'algorithm__reg_lambda': 0.1, 'algorithm__reg...             -49.81
# 4   {'algorithm__reg_lambda': 0.01, 'algorithm__re...             -51.00
# 3   {'algorithm__reg_lambda': 0.01, 'algorithm__re...             -52.46
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 14            -39.91             -40.64           -40.23            0.31
# 0             -40.00             -40.74           -40.30            0.32
# 1             -40.41             -41.01           -40.67            0.25
# 17            -41.45             -41.75           -41.53            0.16
# 15            -41.43             -41.75           -41.53            0.16
# 2             -42.72             -43.16           -42.93            0.18
# 10            -42.90             -43.40           -43.11            0.21
# 24            -42.98             -43.23           -43.14            0.12
# 7             -43.25             -43.41           -43.32            0.07
# 20            -43.45             -43.59           -43.48            0.08
# 12            -43.71             -43.69           -43.61            0.12
# 16            -43.52             -43.91           -43.63            0.20
# 9             -43.24             -44.44           -43.84            0.49
# 6             -43.25             -44.45           -43.85            0.49
# 13            -43.26             -44.45           -43.85            0.49
# 18            -44.54             -44.61           -44.53            0.07
# 23            -44.37             -44.83           -44.55            0.20
# 22            -44.97             -44.86           -44.82            0.14
# 19            -45.59             -45.31           -45.40            0.13
# 21            -45.34             -46.59           -45.97            0.51
# 11            -48.93             -48.70           -48.76            0.12
# 8             -48.86             -49.34           -49.30            0.35
# 5             -49.81             -49.99           -49.87            0.08
# 4             -52.84             -51.98           -51.94            0.75
# 3             -53.47             -53.40           -53.11            0.46
#
#     rank_test_score
# 14                1
# 0                 2
# 1                 3
# 17                4
# 15                5
# 2                 6
# 10                7
# 24                8
# 7                 9
# 20               10
# 12               11
# 16               12
# 9                13
# 6                14
# 13               15
# 18               16
# 23               17
# 22               18
# 19               19
# 21               20
# 11               21
# 8                22
# 5                23
# 4                24
# 3                25
#
# [25 rows x 22 columns]

# %% [markdown]
# ## EVALUATE

# %% [markdown]
# ### Predict over validation

# %%
pred = model.best_estimator_.predict(val_X)

# %% [markdown]
# ### Evaluate over validation

# %%
mae = mean_absolute_error(val_y, pred)
rmse = np.sqrt(mean_squared_error(val_y, pred))
r2 = r2_score(val_y, pred)

print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²: {r2:.3f}")
# Out:
# MAE: 29.03
# RMSE: 40.83
# R²: 0.672

# %% [markdown]
# Target (RUL) range: 0-250
#
# | **Metric** | **Ideal Range** | **Your Value** | **Interpretation Level** | **Quick Explanation (anchored to 0–250)**                                                                                                                                                                              |
# | ---------- | --------------- | -------------- | ------------------------ | ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **MAE**    | < 10% of range  | **30.8**       | 🟢 Good       | **31 cycles**, ~**12%** of the 0–250 range ⇒ solid accuracy                                                                                                      |
# | **RMSE**   | < 15% of range  | **43.9**       | 🟢 Good baseline         | **44 cycles**, ~**17.6%** of the 0–250 range. RMSE penalizes big mistakes more than MAE; here it’s ~1.4× MAE, which is normal (if RMSE were 2× MAE or higher, it’d mean huge outliers) ⇒ some bigger errors exist but aren’t dominant                                   |
# | **R²**     | > 0.6 is solid  | **0.62**       | 🟢 Moderate–good fit     | **62%** of variance explained (0 = just predicting the mean; 1 = perfect) **0.62** means the model captures a **meaningful chunk** of the pattern but still misses ~38% of variability ⇒ room for improvement |

# %% [markdown]
# #### Ad-hoc: 📏 Typical Regression Metric Ranges (generic reference)
#
# | **Metric** | **Excellent**          | **Good**  | **Acceptable** | **Poor** |
# | ---------- | ---------------------- | --------- | -------------- | -------- |
# | **MAE**    | < 10 % of target range | 10–15 %   | 15–25 %        | > 25 %   |
# | **RMSE**   | < 15 % of target range | 15–20 %   | 20–30 %        | > 30 %   |
# | **R²**     | > 0.80                 | 0.60–0.80 | 0.40–0.60      | < 0.40   |
#
#
#
# **⚙️ Why R² ≈ 0.6 and MAE ≈ 12 % are “good” in RUL prediction**
#
# - **The data are noisy** — In CMAPSS and other RUL datasets, sensors capture complex, real-world engine behavior — lots of randomness, environmental variation, and wear patterns that aren’t fully predictable. Even the best models can’t explain all that variance.
# - **The process is nonlinear and multi-factor** — RUL depends on many interacting variables (temperature, pressure, vibration, etc.). That makes perfect prediction (R² → 1) practically impossible — 0.6 – 0.8 is already strong.
# - **Targets often saturate at zero** — Since RUL stops at 0 (failure), you get skewed distributions and hard-to-fit tails. That limits how “tight” your MAE or RMSE can realistically be.
# - **Baseline comparison** — If you just predicted the mean RUL for everything, R² would be 0. So a model explaining ~60 % of the variance (R² = 0.6) is capturing most of the useful signal.
#
# For noisy, nonlinear, real-world problems like RUL prediction, a model that explains ~60 % of variance and stays within ~10–15 % average error of the true range is considered very good — it means the model learned real, actionable patterns instead of random noise.

# %% [markdown]
# ### Best model

# %%
model.best_estimator_
# Out:
# Pipeline(steps=[('algorithm',
#                  HistGradientBoostingRegressor(l2_regularization=0,
#                                                max_depth=10, max_iter=50,
#                                                min_samples_leaf=500,
#                                                scoring='neg_mean_absolute_percentage_error'))])

# %% [markdown]
# HistGradientBoostingRegressor(l2_regularization=0.5,
#                                                learning_rate=0.025,
#                                                max_depth=10, max_iter=200,
#                                                min_samples_leaf=500,
#                                                scoring='neg_mean_absolute_percentage_error')
